# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import time
import traceback
import re
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
master_df_fp = '/Users/sauravyadav/Documents/Repos/Datasets/master_data_draft.csv'

distribution_df_fp = '/Users/sauravyadav/Documents/Repos/Datasets/master_data_distribution_draft.csv'

# %%
df = pd.read_csv(master_df_fp)

# %%
df.head(3)

# %% [markdown]
# ### Total number of participants

# %%
df.SubID.nunique()

# %%
df.shape

# %%
df['SurveyCount'] = df['SurveyCount'].fillna(-1)

# %% [markdown]
# ## Distribution by Survname

# %%
df['SurveyCount'].value_counts()

# %%
# Define the conditions
conditions = [
    (df['SurveyCount'] == 1),
    (df['SurveyCount'] == -1),
    (df['SurveyCount'] == 0),
    (df['SurveyCount'] == 2)
]

# Define the corresponding values
values = ['submission', 'missed (not enough info)', 'missed (penalize)', "missed (don't penalize)"]

# %%
df['SurveyCategory'] = np.select(conditions, values, default=np.nan)
dist_df = df.groupby(['SurvName', 'SurveyCategory']).size().reset_index(name='RecordCount')
pivot_df = dist_df.pivot(index='SurveyCategory', columns='SurvName', values='RecordCount').reset_index()
pivot_df = pivot_df.fillna(0)
display(pivot_df)

# %% [markdown]
# ## Distribution: Pars who submitted at least 1 survey per weekend

# %%
weekend_groups = [[1],[2], [1,2] ,[3],[4],[3,4],[5],[6],[5,6], [1,2,3,4,5,6]]
total_pars = df.SubID.nunique()
res_list = []

for wgp in tqdm(weekend_groups):
    temp_df = df[['SubID', 'Brst', 'Wknd', 'RespType']]
    temp_df = temp_df[(temp_df['RespType'] == 'Submission') & (temp_df['Wknd'].isin(wgp))]
    wgp_readable = ','.join(map(str, wgp))
    res_dict = {'Burst' : temp_df['Brst'].iloc[0], 'Weekend' : wgp_readable}
    
    temp_df = temp_df.groupby(['SubID']).size().reset_index(name='Count')
    
    res_dict['Number of Pars (0)'] = total_pars - temp_df['SubID'].nunique()
    res_dict['Number of Pars (>=1)'] = temp_df[temp_df['Count']>=1]['SubID'].nunique()
    res_dict['Number of Pars (>=1 & <10)'] = temp_df[(temp_df['Count']>=1) & (temp_df['Count']<10)]['SubID'].nunique()
    res_dict['Number of Pars (>=10)'] = temp_df[temp_df['Count'] >= 10]['SubID'].nunique()
    res_list.append(res_dict)

res_dist_df = pd.DataFrame(res_list)

display(res_dist_df)

# %% [markdown]
# ## Distribution: Pars who submitted at least 1 survey per weekend, and survey type

# %%
weekend_groups = [[1],[2], [1,2] ,[3],[4],[3,4],[5],[6],[5,6], [1,2,3,4,5,6]]
total_pars = df.SubID.nunique()
res_list2 = []

for wgp in tqdm(weekend_groups):
    temp_df = df[['SubID', 'Brst', 'Wknd', 'RespType', 'SurvName']]
    temp_df = temp_df[(temp_df['RespType'] == 'Submission') & (temp_df['Wknd'].isin(wgp))]
    wgp_readable = ','.join(map(str, wgp))
    
    temp_df = temp_df.groupby(['SubID', 'SurvName']).size().reset_index(name='Count')

    for survname in temp_df['SurvName'].unique():
        res_dict = {'Weekend' : wgp_readable, 'SurvName':survname}
        temp_survey_df = temp_df[temp_df['SurvName'] == survname]
        res_dict['Number of Pars (0)'] = total_pars - temp_survey_df['SubID'].nunique()
        res_dict['Number of Pars (>=1)'] = temp_survey_df[temp_survey_df['Count']>=1]['SubID'].nunique()
        res_dict['Number of Pars (>=1 & <10)'] = temp_survey_df[(temp_survey_df['Count']>=1) & (temp_survey_df['Count']<10)]['SubID'].nunique()
        res_dict['Number of Pars (>=10)'] = temp_survey_df[temp_survey_df['Count'] >= 10]['SubID'].nunique()
        res_list2.append(res_dict)
    
res_dist2_df = pd.DataFrame(res_list2)

display(res_dist2_df)

# %%
res_dist2_df.head(1)
# Out:
#   Weekend              SurvName  Number of Pars (0)  Number of Pars (>=1)  \
# 0       1  After Your 1st Drink                  10                   383
#
#    Number of Pars (>=1 & <10)  Number of Pars (>=10)
# 0                         383                      0

# %%
melted_df = res_dist2_df.melt(
    id_vars=['Weekend', 'SurvName'],
    value_vars=['Number of Pars (0)', 'Number of Pars (>=1)', 'Number of Pars (>=1 & <10)', 'Number of Pars (>=10)'],
    var_name='Number of Pars Category',
    value_name='Count'
)

# Create a new column by concatenating 'Weekend' and 'SurvName'
melted_df['Weekend_SurvName'] = melted_df['Weekend'].astype(str) + '_' + melted_df['SurvName']

# Pivot the DataFrame to make 'Weekend_SurvName' columns and 'Number of Pars Category' as rows
pivot_df = melted_df.pivot(index='Number of Pars Category', columns='Weekend_SurvName', values='Count').reset_index()

display(pivot_df)
# Out:
# Weekend_SurvName     Number of Pars Category  \
# 0                         Number of Pars (0)
# 1                 Number of Pars (>=1 & <10)
# 2                       Number of Pars (>=1)
# 3                      Number of Pars (>=10)
#
# Weekend_SurvName  1,2,3,4,5,6_After Your 1st Drink  \
# 0                                                3
# 1                                              171
# 2                                              390
# 3                                              219
#
# Weekend_SurvName  1,2,3,4,5,6_Daytime Surveys  \
# 0                                           0
# 1                                          19
# 2                                         393
# 3                                         374
#
# Weekend_SurvName  1,2,3,4,5,6_Drinking Follow-Ups Long  \
# 0                                                    6
# 1                                                   71
# 2                                                  387
# 3                                                  316
#
# Weekend_SurvName  1,2,3,4,5,6_Drinking Follow-Ups Short  \
# 0                                                     4
# 1                                                    56
# 2                                                   389
# 3                                                   333
#
# Weekend_SurvName  1,2,3,4,5,6_Morning Reports  1,2_After Your 1st Drink  \
# 0                                           1                         6
# 1                                          57                       387
# 2                                         392                       387
# 3                                         335                         0
#
# Weekend_SurvName  1,2_Daytime Surveys  1,2_Drinking Follow-Ups Long  \
# 0                                   4                            13
# 1                                  36                           158
# 2                                 389                           380
# 3                                 353                           222
#
# Weekend_SurvName  1,2_Drinking Follow-Ups Short  1,2_Morning Reports  \
# 0                                            10                    4
# 1                                           131                  389
# 2                                           383                  389
# 3                                           252                    0
#
# Weekend_SurvName  1_After Your 1st Drink  1_Daytime Surveys  \
# 0                                     10                  4
# 1                                    383                146
# 2                                    383                389
# 3                                      0                243
#
# Weekend_SurvName  1_Drinking Follow-Ups Long  1_Drinking Follow-Ups Short  \
# 0                                         22                           16
# 1                                        278                          267
# 2                                        371                          377
# 3                                         93                          110
#
# Weekend_SurvName  1_Morning Reports  2_After Your 1st Drink  \
# 0                                 5                      51
# 1                               388                     342
# 2                               388                     342
# 3                                 0                       0
#
# Weekend_SurvName  2_Daytime Surveys  2_Drinking Follow-Ups Long  \
# 0                                16                          71
# 1                               144                         262
# 2                               377                         322
# 3                               233                          60
#
# Weekend_SurvName  2_Drinking Follow-Ups Short  2_Morning Reports  \
# 0                                          68                 20
# 1                                         254                373
# 2                                         325                373
# 3                                          71                  0
#
# Weekend_SurvName  3,4_After Your 1st Drink  3,4_Daytime Surveys  \
# 0                                       71                   60
# 1                                      322                   38
# 2                                      322                  333
# 3                                        0                  295
#
# Weekend_SurvName  3,4_Drinking Follow-Ups Long  3,4_Drinking Follow-Ups Short  \
# 0                                           88                             84
# 1                                          162                            138
# 2                                          305                            309
# 3                                          143                            171
#
# Weekend_SurvName  3,4_Morning Reports  3_After Your 1st Drink  \
# 0                                  61                      88
# 1                                 332                     305
# 2                                 332                     305
# 3                                   0                       0
#
# Weekend_SurvName  3_Daytime Surveys  3_Drinking Follow-Ups Long  \
# 0                                65                         110
# 1                               120                         234
# 2                               328                         283
# 3                               208                          49
#
# Weekend_SurvName  3_Drinking Follow-Ups Short  3_Morning Reports  \
# 0                                         103                 64
# 1                                         232                329
# 2                                         290                329
# 3                                          58                  0
#
# Weekend_SurvName  4_After Your 1st Drink  4_Daytime Surveys  \
# 0                                    103                 65
# 1                                    290                136
# 2                                    290                328
# 3                                      0                192
#
# Weekend_SurvName  4_Drinking Follow-Ups Long  4_Drinking Follow-Ups Short  \
# 0                                        124                          127
# 1                                        229                          221
# 2                                        269                          266
# 3                                         40                           45
#
# Weekend_SurvName  4_Morning Reports  5,6_After Your 1st Drink  \
# 0                                70                        88
# 1                               323                       305
# 2                               323                       305
# 3                                 0                         0
#
# Weekend_SurvName  5,6_Daytime Surveys  5,6_Drinking Follow-Ups Long  \
# 0                                  73                            95
# 1                                  28                           165
# 2                                 320                           298
# 3                                 292                           133
#
# Weekend_SurvName  5,6_Drinking Follow-Ups Short  5,6_Morning Reports  \
# 0                                            94                   72
# 1                                           144                  321
# 2                                           299                  321
# 3                                           155                    0
#
# Weekend_SurvName  5_After Your 1st Drink  5_Daytime Surveys  \
# 0                                    103                 75
# 1                                    290                113
# 2                                    290                318
# 3                                      0                205
#
# Weekend_SurvName  5_Drinking Follow-Ups Long  5_Drinking Follow-Ups Short  \
# 0                                        117                          115
# 1                                        232                          235
# 2                                        276                          278
# 3                                         44                           43
#
# Weekend_SurvName  5_Morning Reports  6_After Your 1st Drink  \
# 0                                75                     113
# 1                               318                     280
# 2                               318                     280
# 3                                 0                       0
#
# Weekend_SurvName  6_Daytime Surveys  6_Drinking Follow-Ups Long  \
# 0                                81                         135
# 1                               135                         211
# 2                               312                         258
# 3                               177                          47
#
# Weekend_SurvName  6_Drinking Follow-Ups Short  6_Morning Reports
# 0                                         127                 79
# 1                                         211                314
# 2                                         266                314
# 3                                          55                  0

# %%
columns_to_keep = ['Number of Pars Category',
    '1_Morning Reports', '1_Daytime Surveys', '1_After Your 1st Drink',
    '2_Morning Reports', '2_Daytime Surveys', '2_After Your 1st Drink',
    '1,2_Morning Reports', '1,2_Daytime Surveys', '1,2_After Your 1st Drink',
    '3_Morning Reports', '3_Daytime Surveys', '3_After Your 1st Drink',
    '4_Morning Reports', '4_Daytime Surveys', '4_After Your 1st Drink',
    '3,4_Morning Reports', '3,4_Daytime Surveys', '3,4_After Your 1st Drink',
    '5_Morning Reports', '5_Daytime Surveys', '5_After Your 1st Drink',
    '6_Morning Reports', '6_Daytime Surveys', '6_After Your 1st Drink',
    '5,6_Morning Reports', '5,6_Daytime Surveys', '5,6_After Your 1st Drink',
    '1,2,3,4,5,6_Morning Reports', '1,2,3,4,5,6_Daytime Surveys', '1,2,3,4,5,6_After Your 1st Drink',
]
display(pivot_df[columns_to_keep])
# Out:
# Weekend_SurvName     Number of Pars Category  1_Morning Reports  \
# 0                         Number of Pars (0)                  5
# 1                 Number of Pars (>=1 & <10)                388
# 2                       Number of Pars (>=1)                388
# 3                      Number of Pars (>=10)                  0
#
# Weekend_SurvName  1_Daytime Surveys  1_After Your 1st Drink  \
# 0                                 4                      10
# 1                               146                     383
# 2                               389                     383
# 3                               243                       0
#
# Weekend_SurvName  2_Morning Reports  2_Daytime Surveys  \
# 0                                20                 16
# 1                               373                144
# 2                               373                377
# 3                                 0                233
#
# Weekend_SurvName  2_After Your 1st Drink  1,2_Morning Reports  \
# 0                                     51                    4
# 1                                    342                  389
# 2                                    342                  389
# 3                                      0                    0
#
# Weekend_SurvName  1,2_Daytime Surveys  1,2_After Your 1st Drink  \
# 0                                   4                         6
# 1                                  36                       387
# 2                                 389                       387
# 3                                 353                         0
#
# Weekend_SurvName  3_Morning Reports  3_Daytime Surveys  \
# 0                                64                 65
# 1                               329                120
# 2                               329                328
# 3                                 0                208
#
# Weekend_SurvName  3_After Your 1st Drink  4_Morning Reports  \
# 0                                     88                 70
# 1                                    305                323
# 2                                    305                323
# 3                                      0                  0
#
# Weekend_SurvName  4_Daytime Surveys  4_After Your 1st Drink  \
# 0                                65                     103
# 1                               136                     290
# 2                               328                     290
# 3                               192                       0
#
# Weekend_SurvName  3,4_Morning Reports  3,4_Daytime Surveys  \
# 0                                  61                   60
# 1                                 332                   38
# 2                                 332                  333
# 3                                   0                  295
#
# Weekend_SurvName  3,4_After Your 1st Drink  5_Morning Reports  \
# 0                                       71                 75
# 1                                      322                318
# 2                                      322                318
# 3                                        0                  0
#
# Weekend_SurvName  5_Daytime Surveys  5_After Your 1st Drink  \
# 0                                75                     103
# 1                               113                     290
# 2                               318                     290
# 3                               205                       0
#
# Weekend_SurvName  6_Morning Reports  6_Daytime Surveys  \
# 0                                79                 81
# 1                               314                135
# 2                               314                312
# 3                                 0                177
#
# Weekend_SurvName  6_After Your 1st Drink  5,6_Morning Reports  \
# 0                                    113                   72
# 1                                    280                  321
# 2                                    280                  321
# 3                                      0                    0
#
# Weekend_SurvName  5,6_Daytime Surveys  5,6_After Your 1st Drink  \
# 0                                  73                        88
# 1                                  28                       305
# 2                                 320                       305
# 3                                 292                         0
#
# Weekend_SurvName  1,2,3,4,5,6_Morning Reports  1,2,3,4,5,6_Daytime Surveys  \
# 0                                           1                            0
# 1                                          57                           19
# 2                                         392                          393
# 3                                         335                          374
#
# Weekend_SurvName  1,2,3,4,5,6_After Your 1st Drink
# 0                                                3
# 1                                              171
# 2                                              390
# 3                                              219
